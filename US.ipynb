# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\htran\Downloads\US\2022_US_Region_Mobility_.csv', index_col=False)

# %%
df
# Out:
#        sub_region_1   sub_region_2  metro_area iso_3166_2_code  \
# 0               NaN            NaN         NaN             NaN
# 1               NaN            NaN         NaN             NaN
# 2               NaN            NaN         NaN             NaN
# 3               NaN            NaN         NaN             NaN
# 4               NaN            NaN         NaN             NaN
# ...             ...            ...         ...             ...
# 352716      Wyoming  Weston County         NaN             NaN
# 352717      Wyoming  Weston County         NaN             NaN
# 352718      Wyoming  Weston County         NaN             NaN
# 352719      Wyoming  Weston County         NaN             NaN
# 352720      Wyoming  Weston County         NaN             NaN
#
#         census_fips_code                     place_id       date  \
# 0                    NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw   1/1/2022
# 1                    NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw   1/2/2022
# ...

# %%
df = df.drop(df.index[df['sub_region_1'].isnull()])

# %%
df
# Out:
#        sub_region_1   sub_region_2  metro_area iso_3166_2_code  \
# 136         Alabama            NaN         NaN           US-AL
# 137         Alabama            NaN         NaN           US-AL
# 138         Alabama            NaN         NaN           US-AL
# 139         Alabama            NaN         NaN           US-AL
# 140         Alabama            NaN         NaN           US-AL
# ...             ...            ...         ...             ...
# 352716      Wyoming  Weston County         NaN             NaN
# 352717      Wyoming  Weston County         NaN             NaN
# 352718      Wyoming  Weston County         NaN             NaN
# 352719      Wyoming  Weston County         NaN             NaN
# 352720      Wyoming  Weston County         NaN             NaN
#
#         census_fips_code                     place_id       date  \
# 136                  NaN  ChIJdf5LHzR_hogR6czIUzU0VV4   1/1/2022
# 137                  NaN  ChIJdf5LHzR_hogR6czIUzU0VV4   1/2/2022
# ...

# %%
df.pop('iso_3166_2_code')
# Out:
# 136       US-AL
# 137       US-AL
# 138       US-AL
# 139       US-AL
# 140       US-AL
#           ...
# 352716      NaN
# 352717      NaN
# 352718      NaN
# 352719      NaN
# 352720      NaN
# Name: iso_3166_2_code, Length: 352585, dtype: object

# %%
df
# Out:
#        sub_region_1   sub_region_2  metro_area  census_fips_code  \
# 136         Alabama            NaN         NaN               NaN
# 137         Alabama            NaN         NaN               NaN
# 138         Alabama            NaN         NaN               NaN
# 139         Alabama            NaN         NaN               NaN
# 140         Alabama            NaN         NaN               NaN
# ...             ...            ...         ...               ...
# 352716      Wyoming  Weston County         NaN           56045.0
# 352717      Wyoming  Weston County         NaN           56045.0
# 352718      Wyoming  Weston County         NaN           56045.0
# 352719      Wyoming  Weston County         NaN           56045.0
# 352720      Wyoming  Weston County         NaN           56045.0
#
#                            place_id       date  \
# 136     ChIJdf5LHzR_hogR6czIUzU0VV4   1/1/2022
# 137     ChIJdf5LHzR_hogR6czIUzU0VV4   1/2/2022
# ...

# %%
df = df.dropna(subset=['retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline'], how='all')

# %%
df
# Out:
#        sub_region_1   sub_region_2  metro_area  census_fips_code  \
# 136         Alabama            NaN         NaN               NaN
# 137         Alabama            NaN         NaN               NaN
# 138         Alabama            NaN         NaN               NaN
# 139         Alabama            NaN         NaN               NaN
# 140         Alabama            NaN         NaN               NaN
# ...             ...            ...         ...               ...
# 352716      Wyoming  Weston County         NaN           56045.0
# 352717      Wyoming  Weston County         NaN           56045.0
# 352718      Wyoming  Weston County         NaN           56045.0
# 352719      Wyoming  Weston County         NaN           56045.0
# 352720      Wyoming  Weston County         NaN           56045.0
#
#                            place_id       date  \
# 136     ChIJdf5LHzR_hogR6czIUzU0VV4   1/1/2022
# 137     ChIJdf5LHzR_hogR6czIUzU0VV4   1/2/2022
# ...

# %%
df.rename(columns= {'sub_region_1':'state'}, inplace=True)

# %%
df
# Out:
#           state   sub_region_2  metro_area  census_fips_code  \
# 136     Alabama            NaN         NaN               NaN
# 137     Alabama            NaN         NaN               NaN
# 138     Alabama            NaN         NaN               NaN
# 139     Alabama            NaN         NaN               NaN
# 140     Alabama            NaN         NaN               NaN
# ...         ...            ...         ...               ...
# 352716  Wyoming  Weston County         NaN           56045.0
# 352717  Wyoming  Weston County         NaN           56045.0
# 352718  Wyoming  Weston County         NaN           56045.0
# 352719  Wyoming  Weston County         NaN           56045.0
# 352720  Wyoming  Weston County         NaN           56045.0
#
#                            place_id       date  \
# 136     ChIJdf5LHzR_hogR6czIUzU0VV4   1/1/2022
# 137     ChIJdf5LHzR_hogR6czIUzU0VV4   1/2/2022
# 138     ChIJdf5LHzR_hogR6czIUzU0VV4   1/3/2022
# ...

# %%
df.pop('metro_area')
# Out:
# 136      NaN
# 137      NaN
# 138      NaN
# 139      NaN
# 140      NaN
#           ..
# 352716   NaN
# 352717   NaN
# 352718   NaN
# 352719   NaN
# 352720   NaN
# Name: metro_area, Length: 352585, dtype: float64

# %%
df
# Out:
#           state   sub_region_2  census_fips_code                     place_id  \
# 136     Alabama            NaN               NaN  ChIJdf5LHzR_hogR6czIUzU0VV4
# 137     Alabama            NaN               NaN  ChIJdf5LHzR_hogR6czIUzU0VV4
# 138     Alabama            NaN               NaN  ChIJdf5LHzR_hogR6czIUzU0VV4
# 139     Alabama            NaN               NaN  ChIJdf5LHzR_hogR6czIUzU0VV4
# 140     Alabama            NaN               NaN  ChIJdf5LHzR_hogR6czIUzU0VV4
# ...         ...            ...               ...                          ...
# 352716  Wyoming  Weston County           56045.0  ChIJd4Rqhed3YocR7ubT5-HgoJg
# 352717  Wyoming  Weston County           56045.0  ChIJd4Rqhed3YocR7ubT5-HgoJg
# 352718  Wyoming  Weston County           56045.0  ChIJd4Rqhed3YocR7ubT5-HgoJg
# 352719  Wyoming  Weston County           56045.0  ChIJd4Rqhed3YocR7ubT5-HgoJg
# 352720  Wyoming  Weston County           56045.0  ChIJd4Rqhed3YocR7ubT5-HgoJg
#
# ...
